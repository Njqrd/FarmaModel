# %%
from openbb_terminal.sdk import openbb
openbb.__version__

openbb.login(token="eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhdXRoX3Rva2VuIjoiMmNXQ1FHWUlaNGpUTHlmeWJ6dWJ6UWN1UTBmUXNMa0hiVVdFMjBhQSIsImV4cCI6MTc0MDc0OTQ4MH0.y5KZhm_iUIo52hfegVwW-NM-28Q6AOaHrdyHd6bhGi8", keep_session=True)
# Out:
# Creating session from token.
# Token expires at 2025-02-28 14:31:20
# Login successful.

# %%
StockScreenerStocks=['CRVL','GWW','MEDP','MANH','AVGO','WSM','MLI','KLAC','ATKR','FIX','CF','ON','SKY','SMCI','PHM','HUBB','NVR','AOS','COKE','AAPL','BCC','PBF','AIT','BLDR','POOL','MSFT','SSD','CDNS','EXP','MUSA','ANET','AAON','MGY','SWN','DHI','WTS','CTAS','GOOG','IT','ITW','IPAR','BRKR','UFPI','DE','FTNT','QLYS','ADSK','NVDA','LSCC','HRB','TOL','GOOGL','LII','AN','WES','MSI','DKS','CMG','FAST','SAIA','ALSN','OVV','WSO','MTDR','MTH','IBP','CHDN','IR','BLD','AMAT','TMHC','LRCX','MA','LECO','ABG','NUE','URI','SNA','WAT','CMC','ITT','ELF','TSCO','ALB','TNET','EME','VLO','FSS','STLD','MCHP','MPC','EXLS','CNM','ODFL','EOG','RS','ULTA','OC','SCCO','MTD','CAT','PCAR','META','NEU','SYY','WSO.B','ACI','TTEK','ALGM','MCO','DDS','FN','BMI','CDW','GILD','CE','EXPD','LEN.B','JBL','V','HD','ZTS','IPG','AMG','LSTR','LLY','PXD','CHK','TJX','FELE','PAG','GPK','RHI','WST','MPWR','LEN','ENPH','SUN','VRSK','IBM','PH','AGCO','CBOE','VVV','MOH','NXT','SHW','UNH','GEN','DECK','PAYX','TXN','SNPS','HESM','SPSC','BR','COP','SUM','TSLA','PSX','SFM','BKNG','FDS','NOW','BJ','GOLF','SEIC','RRC','ADP','IDXX','VRTX','APH','DINO','MMC','LW','CLH','CIVI','MSM','TXRH','ROL','APA','HSY','WM','WMB','CPRT','HLNE','TPL','CROX','COST','WCC','CBT','MOG.B','NKE','A','CELH','AYI','GGG','KNSL','LMT','DOV','UNP','KBH','BC','FANG','MRO','CSCO','MLM','NDSN','JBHT','SEE','ASO','FMC','UPS','TPX','ORCL','KEYS','RL','DXCM','ATI','PEP','NSIT','VNOM','DELL','TREX','ONTO','NFLX','SKX','GPC','LKQ','ROK','CHH','RPM','RLI','CTRA','ADBE','CSL','ISRG','OMC','IEX','WLK','RRR','AMGN','CSX','BSY','KO','MKTX','CL','CHE','PR','AXP','CASY','HWM','INTU','AMP','WH','SCI','DRI','AVY','ACT','BYD','ERIE','MOG.A','AFG','NOVT','DCI','RMBS','COR','WU','PG','PKG','WMS','PII','ROST','MNST','PAYC','THC','ABBV','INGR','MIDD','DOCS','NXST','QCOM','MSTR','RSG','DFS','ARW','MAR','WRB','HIG','AME','TROW','SYK','EPAM','FCFS','HON','DVN','ELV','HOG','PTC','REGN','SWAV','AEL','EBAY','BF.A','TXT','EPD','EW','AWI','EVR','BWXT','SM','WAB','BCPC','OPCH','AMR','BAH','GD','OKE','PPG','RDN','VMI','MMSI','BF.B','VNT','GNTX','JKHY','IQV','TTC','DG','VEEV','XYL','APD','EQT','KMB','FLT','NTAP','MTG','ADI','FCN','MPLX','PFG','ECL','RMD','FIZZ','PYPL','FFIV','GIS','HII','OLN','ABNB','TW','HLI','M','J','LPLA','AXON','BLK','MDLZ','VMC','AFL','LFUS','ADM','PGR','EHC','SAIC','RH','TKR','SITE','SON','SPXC','VOYA','ANF','FBIN','DVA','AM','ENSG','SLM','GE','KMI','EFX','DOX','CARR','CINF','CHX','UTHR','CW','FIVE','AMKR','FUL','FND','AR','CTSH','CRL','DAR','CPB','ESAB','KR','EXEL','PODD','GATX','HXL','ET','CI','ENLC','TECH','DV','SYF','LAD','CHRD','MKL','AIG','TER','GL','BG','UNM','BRK.A','PRI','FI','CHRW','CRUS','TRGP','MUR','BRK.B','CRBG','RJF','HALO','HEI','BRO','PWR','MMS','JNJ','BEN','ASGN','NYT','MTN','FDX','HUM','MDU','BURL','NDAQ','RCL','K','EQH','TMUS','ZM','XOM','EXPE','HES','CHD','BERY','ROP','CHTR','ABT','HGV','SWKS','FTAI','CVX','RBA','MGM','HAL','VTRS','COF','OXY','OLED','LEA','PFGC','ACHC','WMT','DLTR','LANC','OMF','YETI','TPR','ALGN','LYV','CMCSA','GEHC','HEI.A','CWST','EMR','ANSS','TDY','SLGN','AIZ','BMY','COLM','SIGI','ZBRA','CME','SPGI','ORI','PCTY','OSK','COOP','BALL','LSXMK','EA','LSXMB','CACC','LSXMA','NE','AXTA','MDC','WWD','FCX','RBC','TRV','DAL','SLB','SCHW','NOC','IPGP','CNC','OLLI','UHS','FLS','RGEN','DGX','TKO','CNA','NBIX','BK','JXN','USFD','EEFT','BDX','SAM','AKAM','TMO','MATX','REYN','DTM','SNDR','EMN','NSC','AJG','AZPN','ESI','GS','WSC','SNX','HSIC','TGT','CGNX','NOV','FG','DHR','AMZN','BBY','MS','ACM','LNW','CVS','FOUR','ATR','ETRN','IBKR','PANW','WMG','UHAL','COO','PPC','LPX','MAT','THO','BSX','PAA','TFX','FLR','GM','FOXA','DT','H','CNXC','AEO','KNX','LVS','LBRDA','MTCH','CCK','JEF','KEX','MTSI','PFSI','RGLD','FNF','WFRD','STT','LH','LBRDK','IAC','MRK','COTY','FSLR','JNPR','DLB','SF','APG','BKR','CLX','CPNG','STWD','MKC.V','STZ','CACI','MKC','PTEN','HLT','UHAL.B','MET','ALTR','PSN','MOS','GME','ASH','POWI','PEN','NTRS','IP','BWA','VRT','CRM','ICE','KDP','NFE','HOLX','BECN','KHC','ZBH','HPE','WHR','HRL','CMI','SSNC','ARMK','R','FOX','DRS','XPO','AMD','ALLY','INCY','LHX','EL','CTVA','PVH','TRMB','GTLS','PFE','HUN','FTV','FAF','INTC','FLO','L','RGA','TYL','CYTK','CNNE','KVUE','BIIB','CAG','GLW','X','DOW','AZEK','NWS','DUOL','NWSA','UAL','UBER','GMED','FWONK','MASI','VZ','KBR','FWONA','TTD','MSA','APPF','WEX','RVTY','TAP','PCVX','RYAN','WTM','RKT','ALL','F','DDOG','MARA','WDAY','ZWS','CIEN','AA','CLF','CZR','T','UWMC','CC','TRU','NEM','GPN','LAZ','GFS','ITCI','BATRK','THG','PRU','MORN','SYM','GNRC','PSTG','ADT','CAVA','IFF','ENTG','ETSY','PINS','BROS','CTLT','TAP.A','GXO','DD','SLAB','LEVI','APP','NUVL','SYNA','RTX','SOFI','KMX','ALK','RITM','IRDM','BMRN','AL','POST','PWSC','IVZ','LEGN','MTZ','MHK','FIVN','BAX','HUBS','CHWY','GPS','DOCU','SJM','KRTX','BFAM','HCP','RRX','BILL','ALNY','TTWO','IMVT','LDOS','HOOD','MDB','XRAY','DAY','HQY','MU','COIN','QRVO','LUV','GWRE','ILMN','PLTR','DNB','NET','DASH','SNOW','RPRX','MRVL','LNC','GKOS','WBA','SGRY','ST','INFA','EDR','AGNC','COHR','INSP','BIO','SWK','DIS','AVTR','BIO.B','IOT','AXSM','SHC','VFC','AUR','OWL','WRK','FRSH','TEAM','AFRM','FYBR','ASAN','CWAN','CART','QDEL','PCOR','ZI','WDC','CERE','CCL','SPLK','MMM','RVMD','RCM','SMAR','ALIT','ACAD','TSN','KD','FRPT','ELAN','CCCS','SQ','WK','DKNG','FIS','MDGL','IEP','SNAP','GTLB','TWLO','VRNS','RIVN','MRNA','CFLT','HAS','MKSI','EXAS','CRWD','SRCL','NLY','TXG','PEGA','ROKU','TOST','APLS','BRZE','CVNA','IONS','PATH','U','NCLH','WBD','PARAA','JOBY','PARA','SRPT','ZS','RBLX','BPMC','TENB','NTRA','S','OKTA','LCID','LYFT']

# %% [markdown]
# # Lets get the stock list

# %%
import requests
import pandas as pd

# Replace 'YOUR_API_KEY' with your actual API key
url = "https://financialmodelingprep.com/api/v3/financial-statement-symbol-lists?apikey=8091977efbbd21197bf80d9b4ca870c8"
response = requests.get(url)
data = response.json()

# Convert the list of tradeable stocks into a DataFrame
df = pd.DataFrame(data)
print(df.head())  # This prints the first few rows of the DataFrame
# Out:
#            0
# 0  000001.SZ
# 1  000002.SZ
# 2  000004.SZ
# 3  000005.SZ
# 4  000006.SZ

# %%
print("There are "+str(df.shape[0])+" stocks with fa information")
# Out:
# There are 59448 stocks with fa information

# %% [markdown]
# ## Load Historical Stock Price Data

# %%
StockPriceData = openbb.stocks.load("PDCO")
StockPriceData
# Out:
# Loading Daily data for PDCO with starting period 2021-03-08.
#                  Open       High        Low      Close  Adj Close   Volume  \
# date
# 2021-03-08  27.935433  28.836576  27.755203  28.241821  28.241821   541400
# 2021-03-09  28.719422  29.251095  28.097633  28.331930  28.331930  1033900
# 2021-03-10  28.809541  29.431330  28.611290  28.674370  28.674370   578900
# 2021-03-11  28.845585  29.160987  28.124671  28.476118  28.476118   801600
# 2021-03-12  28.376989  28.800525  28.241818  28.638321  28.638321   582400
# ...               ...        ...        ...        ...        ...      ...
# 2024-03-05  27.090000  27.280001  26.549999  26.760000  26.760000   666400
# 2024-03-06  26.809999  27.020000  26.500000  26.850000  26.850000   683700
# 2024-03-07  27.030001  27.110001  26.799999  27.020000  27.020000   665800
# 2024-03-08  27.170000  27.360001  26.990000  27.170000  27.170000   610200
# 2024-03-11  27.280001  27.280001  26.760000  27.160000  27.160000   568200
#
# ...

# %% [markdown]
# ## Get Balance Sheet for a stock

# %%
Balance = openbb.stocks.fa.balance("PDCO")
Balance
# Out:
#                                               2023-04-30    2022-04-30  \
# Breakdown
# Cash and cash equivalents                   1.596690e+08  1.420140e+08
# Total cash                                  1.596690e+08  1.420140e+08
# Net receivables                             4.773840e+08  4.471620e+08
# Inventory                                   7.950720e+08  7.856040e+08
# Other current assets                        3.510110e+08  3.042420e+08
# Total current assets                        1.783136e+09  1.679022e+09
# Gross property plant and equipment          7.203210e+08  6.922150e+08
# Accumulated depreciation                   -4.150820e+08 -4.083530e+08
# Net property plant and equipment            3.052390e+08  2.838620e+08
# Equity and other investments                1.600220e+08  1.391820e+08
# Goodwill                                    1.564200e+08  1.406300e+08
# Intangible assets                           2.318730e+08  2.526140e+08
# ...

# %% [markdown]
# ## Get income statement for stock

# %%
income = openbb.stocks.fa.income("PDCO")
income
# Out:
#                                                       ttm    2023-04-30  \
# Breakdown
# Total revenue                                6.566764e+09  6.471471e+09
# Cost of revenue                              5.167916e+09  5.098526e+09
# Gross profit                                 1.398848e+09  1.372945e+09
# Total operating expenses                     1.128601e+09  1.096974e+09
# Operating income or loss                     2.702470e+08  2.759710e+08
# Interest expense                             4.267700e+07  3.363600e+07
# Total other income/expenses net              2.739700e+07  2.782600e+07
# Income before tax                            2.549670e+08  2.701610e+08
# Income tax expense                           6.154700e+07  6.356300e+07
# Income from continuing operations            1.934200e+08  2.065980e+08
# Net income                                   1.938600e+08  2.075570e+08
# Net income available to common shareholders  1.938600e+08  2.075570e+08
# ...

# %%
import requests

def stock_screener(api_key, marketCapMoreThan=None, marketCapLowerThan=None, priceMoreThan=None, priceLowerThan=None, betaMoreThan=None, betaLowerThan=None, volumeMoreThan=None, volumeLowerThan=None, dividendMoreThan=None, dividendLowerThan=None, isEtf=None, isFund=None, isActivelyTrading=None, sector=None, industry=None, country=None, exchange=None, limit=None):
    base_url = "https://financialmodelingprep.com/api/v3/stock-screener"
    params = {
        "apikey": api_key,
        "marketCapMoreThan": marketCapMoreThan,
        "marketCapLowerThan": marketCapLowerThan,
        "priceMoreThan": priceMoreThan,
        "priceLowerThan": priceLowerThan,
        "betaMoreThan": betaMoreThan,
        "betaLowerThan": betaLowerThan,
        "volumeMoreThan": volumeMoreThan,
        "volumeLowerThan": volumeLowerThan,
        "dividendMoreThan": dividendMoreThan,
        "dividendLowerThan": dividendLowerThan,
        "isEtf": isEtf,
        "isFund": isFund,
        "isActivelyTrading": isActivelyTrading,
        "sector": sector,
        "industry": industry,
        "country": country,
        "exchange": exchange,
        "limit": limit
    }
    response = requests.get(base_url, params={k: v for k, v in params.items() if v is not None})
    if response.status_code == 200:
        return response.json()
    else:
        return {"error": "Failed to fetch data", "status_code": response.status_code}

# Example usage:
api_key = "8091977efbbd21197bf80d9b4ca870c8"
result = stock_screener(api_key, marketCapMoreThan=4000000000, isActivelyTrading=True, country="US", isFund = False)
# print(result)

# %%
len(result)
# Out:
# 1000

# %%
import pandas as pd
result = stock_screener(api_key, marketCapMoreThan=4000000000, isActivelyTrading=True, country="US", isFund = False)
test = pd.DataFrame(result)

# %%
test['exchangeShortName'].unique()
# Out:
# array(['PNK', 'BUE', 'MEX', 'LSE', 'NEO', 'NASDAQ', 'XETRA', 'NSE', 'TLV',
#        'NYSE', 'VIE', 'SIX', 'AMEX', 'JNB', 'EURONEXT', 'ETF', 'KSC',
#        'ASX', 'TSX', 'CPH', 'JPX'], dtype=object)

# %%
test
# Out:
#       symbol                        companyName          marketCap  \
# 0      NSARP   NSTAR Electric Company PFD 4.25%  24821997200550000
# 1     UNH.BA    UnitedHealth Group Incorporated    510340888108053
# 2       V.BA                          Visa Inc.    476368477449308
# 3    COST.BA       Costco Wholesale Corporation    272340889892592
# 4    ABBV.BA                        AbbVie Inc.    267513781827150
# ..       ...                                ...                ...
# 995   0R1R.L                    Kellogg Company        18422162850
# 996   0JZS.L  McCormick & Company, Incorporated        18405500909
# 997   OVV.TO                       Ovintiv Inc.        18397093900
# 998   0HYE.L   Cincinnati Financial Corporation        18392471000
# 999     CINF   Cincinnati Financial Corporation        18389337700
#
#                  sector                       industry   beta      price  \
# 0                                                 None  0.000     70.950
# ...

# %%
exchanges = ['NASDAQ', 'NYSE', 'AMEX', 'CBOE', 'PNK']

# %%
sectorsToExclude = ["Real Estate","Utilities",""]
industryToExclude = ["Banks—Regional","Banks—Diversified"]

# %%
result = stock_screener(api_key, marketCapMoreThan=4000000000, isActivelyTrading=True, country="US", isFund = False, isEtf = False, exchange='NASDAQ')
NASDAQ = pd.DataFrame(result)

# %%
NASDAQ
# Out:
#     symbol                    companyName      marketCap  \
# 0     MSFT          Microsoft Corporation  3005761588800
# 1     AAPL                     Apple Inc.  2667588225000
# 2     NVDA             NVIDIA Corporation  2144350000000
# 3     AMZN               Amazon.com, Inc.  1786217304000
# 4     GOOG                  Alphabet Inc.  1721374744682
# ..     ...                            ...            ...
# 356   COLB  Columbia Banking System, Inc.     4074465780
# 357   INSM            Insmed Incorporated     4021163360
# 358   EXPO                 Exponent, Inc.     4018763136
# 359    SYM                  Symbotic Inc.     4013091600
# 360   CRVL             CorVel Corporation     4000237143
#
#                      sector                        industry   beta   price  \
# 0                Technology         Software—Infrastructure  0.890  404.52
# 1                Technology            Consumer Electronics  1.289  172.75
# ...

# %%
filtered_df = NASDAQ[~NASDAQ['industry'].isin(industryToExclude)]
filtered_df = filtered_df[~filtered_df['sector'].isin(sectorsToExclude)]
filtered_dfNASDAQ = filtered_df[~filtered_df['symbol'].isin(StockScreenerStocks)]

# %%
filtered_dfNASDAQ.shape
# Out:
# (31, 15)

# %%
filtered_dfNASDAQ = filtered_dfNASDAQ.query('marketCap>50000000000')
filtered_dfNASDAQ
# Out:
#    symbol                companyName     marketCap             sector  \
# 30   SBUX      Starbucks Corporation  104241654000  Consumer Cyclical
# 47   ORLY  O'Reilly Automotive, Inc.   64121422358  Consumer Cyclical
#
#             industry   beta    price  lastAnnualDividend   volume  \
# 30       Restaurants  0.982    92.07                2.28  6474607
# 47  Specialty Retail  0.862  1086.13                0.00   218214
#
#                 exchange exchangeShortName country  isEtf  isFund  \
# 30  NASDAQ Global Select            NASDAQ      US  False   False
# 47  NASDAQ Global Select            NASDAQ      US  False   False
#
#     isActivelyTrading
# 30               True
# 47               True

# %%
filtered_df = NYSE[~NYSE['industry'].isin(industryToExclude)]
filtered_df = filtered_df[~filtered_df['sector'].isin(sectorsToExclude)]
filtered_dfNYSE = filtered_df[~filtered_df['symbol'].isin(StockScreenerStocks)]

# %%
filtered_dfNYSE.shape
# Out:
# (56, 15)

# %%
filtered_dfNYSE = filtered_dfNYSE.query('marketCap>50000000000')

# %%
filtered_dfNYSE.shape
# Out:
# (14, 15)

# %%
filtered_dfNYSE
# Out:
#     symbol                       companyName     marketCap  \
# 0    BRK-B           Berkshire Hathaway Inc.  876524250247
# 1    BRK-A           Berkshire Hathaway Inc.  872167270260
# 20     MCD            McDonald's Corporation  213178632480
# 35      BX                   Blackstone Inc.  151520073092
# 36      PM  Philip Morris International Inc.  146443551800
# 38     LOW            Lowe's Companies, Inc.  138659744300
# 51      BA                The Boeing Company  117597419900
# 65     KKR                    KKR & Co. Inc.   86341185360
# 67     HCA              HCA Healthcare, Inc.   84787799440
# 75      MO                Altria Group, Inc.   75308559300
# 83     MCK              McKesson Corporation   69211278993
# 91     TDG      TransDigm Group Incorporated   64172728547
# 96     APO    Apollo Global Management, Inc.   61651150110
# 111    AZO                    AutoZone, Inc.   53050165848
#
#                  sector                 industry   beta       price  \
# ...

# %%
import yfinance as yf
count = 0 

import yfinance as yf

# Assuming NASDAQ and NYSE are DataFrames with a 'symbol' column
NASDAQ_symbols = NASDAQ['symbol'].tolist()
NYSE_symbols = NYSE['symbol'].tolist()

count = 0

for stock in StockScreenerStocks:
    if stock not in NASDAQ_symbols and stock not in NYSE_symbols:
        # print("Symbol:"stock)
        stock_info = yf.Ticker(stock)
        market_cap = stock_info.info.get("marketCap", "No MarketCap")
        print(f"Stock: {stock}, Market Cap: {market_cap}")
        print("Name:", stock_info.info.get("longName", "No Name"))
        print("Industry:", stock_info.info.get("industry", "No Industry"))
        print("Sector:", stock_info.info.get("sector", "No Sector"))
        
            

        count += 1

print("Total stocks processed:", count)
# Out:
# Stock: WSO.B, Market Cap: No MarketCap
# Name: No Name
# Industry: No Industry
# Sector: No Sector
# Stock: FN, Market Cap: 7326671872
# Name: Fabrinet
# Industry: Electronic Components
# Sector: Technology
# Stock: LEN.B, Market Cap: No MarketCap
# Name: No Name
# Industry: No Industry
# Sector: No Sector
# Stock: CBOE, Market Cap: 19409139712
# Name: Cboe Global Markets, Inc.
# Industry: Financial Data & Stock Exchanges
# Sector: Financial Services
# Stock: MOG.B, Market Cap: No MarketCap
# Name: No Name
# Industry: No Industry
# Sector: No Sector
# Stock: RRR, Market Cap: 5792075264
# Name: Red Rock Resorts, Inc.
# Industry: Resorts & Casinos
# Sector: Consumer Cyclical
# Stock: MOG.A, Market Cap: No MarketCap
# Name: No Name
# Industry: No Industry
# Sector: No Sector
# Stock: BF.A, Market Cap: No MarketCap
# Name: No Name
# Industry: No Industry
# Sector: No Sector
# Stock: BF.B, Market Cap: No MarketCap
# Name: No Name
# Industry: No Industry
# Sector: No Sector
# ...

# %%
industry_counts = {}
sector_counts = {}
marketcapCount = 0
for stock in StockScreenerStocks:
    if stock not in NASDAQ_symbols and stock not in NYSE_symbols:
        stock_info = yf.Ticker(stock)
        market_cap = stock_info.info.get("marketCap", "No MarketCap")
        print(f"Stock: {stock}, Market Cap: {market_cap}")
        print("Name:", stock_info.info.get("longName", "No Name"))
        
        industry = stock_info.info.get("industry", "No Industry")
        sector = stock_info.info.get("sector", "No Sector")
        if market_cap != "No MarketCap":
            if int(market_cap) < 4000000000:
                marketcapCount+=1
        print("Industry:", industry)
        print("Sector:", sector)
        
        # Update industry counts
        if industry in industry_counts:
            industry_counts[industry] += 1
        else:
            industry_counts[industry] = 1
        
        # Update sector counts
        if sector in sector_counts:
            sector_counts[sector] += 1
        else:
            sector_counts[sector] = 1

# Print industry and sector counts
print("\nIndustry Counts:")
for industry, count in industry_counts.items():
    print(f"{industry}: {count}")

print("\nSector Counts:")
for sector, count in sector_counts.items():
    print(f"{sector}: {count}")
# Out:
# Stock: WSO.B, Market Cap: No MarketCap
# Name: No Name
# Industry: No Industry
# Sector: No Sector
# Stock: FN, Market Cap: 7326671872
# Name: Fabrinet
# Industry: Electronic Components
# Sector: Technology
# Stock: LEN.B, Market Cap: No MarketCap
# Name: No Name
# Industry: No Industry
# Sector: No Sector
# Stock: CBOE, Market Cap: 19409139712
# Name: Cboe Global Markets, Inc.
# Industry: Financial Data & Stock Exchanges
# Sector: Financial Services
# Stock: MOG.B, Market Cap: No MarketCap
# Name: No Name
# Industry: No Industry
# Sector: No Sector
# Stock: RRR, Market Cap: 5792075264
# Name: Red Rock Resorts, Inc.
# Industry: Resorts & Casinos
# Sector: Consumer Cyclical
# Stock: MOG.A, Market Cap: No MarketCap
# Name: No Name
# Industry: No Industry
# Sector: No Sector
# Stock: BF.A, Market Cap: No MarketCap
# Name: No Name
# Industry: No Industry
# Sector: No Sector
# Stock: BF.B, Market Cap: No MarketCap
# Name: No Name
# Industry: No Industry
# Sector: No Sector
# ...

# %%
marketcapCount
# Out:
# 16

# %%
import pandas as pd

# Given Fama-French Three-Factor Model factor values
excess_return = 0.06
mkt_rf_factor = 0.070
smb_factor = -0.0507
hml_factor = -0.0239
rf_factor = 0.0047

# Assume you have already calculated annual excess return (from Step 7)
res = {
    'Excess Return': excess_return,
    'MKT-RF': mkt_rf_factor,
    'SMB': smb_factor,
    'HML': hml_factor,
    'RF': rf_factor
}

# Create a DataFrame with a specified index (e.g., a single row with index 0)
fama_french_data = pd.DataFrame(res, index=[0])

# %%
import statsmodels.api as sm

# Define independent variables (factors) and dependent variable (MSFT excess return)
X = fama_french_data[['MKT-RF', 'SMB', 'HML', 'RF']]
y = fama_french_data['Excess Return']

# Add a constant term to the independent variables
X = sm.add_constant(X)

# Run the regression model
model = sm.OLS(y, X).fit()

# Get regression results
# print(model.summary())

# %%
import statsmodels.api as sm

# Define independent variables (factors) and dependent variable (MSFT excess return)
X = fama_french_data[['MKT-RF', 'SMB', 'HML', 'RF']]
y = fama_french_data['Excess Return']

# Add a constant term to the independent variables
X = sm.add_constant(X)

# Run the regression model
model = sm.OLS(y, X).fit()

# Get regression results
# print(model.summary())

# Print the residuals
residuals = model.resid
print("Residuals:")
print(residuals)

# Check for normality using Jarque-Bera test
try:
    jb, jbpv, skew, kurtosis = sm.stats.jarque_bera(residuals)
    print(f"Jarque-Bera Test: JB = {jb}, p-value = {jbpv}")
except ValueError as e:
    print(f"Error in Jarque-Bera test: {e}")
# Out:
# Residuals:
# 0    3.469446951953614e-17
# dtype: object
# Error in Jarque-Bera test: resids must contain at least 2 elements
